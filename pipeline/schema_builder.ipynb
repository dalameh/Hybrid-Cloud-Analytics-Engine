# %%
# %sql
CREATE EXTERNAL LOCATION olist_datalake_root
URL 's3://olist-ecommerce-prod-useast1-datalake/'
WITH (STORAGE CREDENTIAL `db_s3_credentials_databricks-s3-ingest-7b60f`);

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS olist_raw_landing_zone
URL 's3://olist-ecommerce-landing-bucket/landing/'
WITH (STORAGE CREDENTIAL `db_s3_credentials_databricks-s3-ingest-7b60f`);

# %%
# %sql
CREATE CATALOG IF NOT EXISTS olist_prod 
MANAGED LOCATION 's3://olist-ecommerce-prod-useast1-datalake/';

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS olist_prod.bronze;
CREATE SCHEMA IF NOT EXISTS olist_prod.silver;
CREATE SCHEMA IF NOT EXISTS olist_prod.gold;

# %%
# %sql
SHOW EXTERNAL LOCATIONS;
